# %%
import pandas as pd
from knowledgebase import KB, extract_triples
from knowledgegraph import KG

# %%
import pickle
with open('kb_comp.pickle', 'rb') as handle:
    kb_comp = pickle.load(handle)

# %%
# Out:
# [{'head': 'Quartet Health',
#   'type': 'category_list',
#   'tail': 'Artificial Intelligence'},
#  {'head': 'Quartet Health',
#   'type': 'category_list',
#   'tail': 'Data and Analytics'},
#  {'head': 'Quartet Health', 'type': 'category_list', 'tail': 'Health Care'},
#  {'head': 'Quartet Health',
#   'type': 'category_list',
#   'tail': 'Information Technology'},
#  {'head': 'Quartet Health', 'type': 'category_list', 'tail': 'Software'},
#  {'head': 'Turing.com',
#   'type': 'category_list',
#   'tail': 'Information Technology'},
#  {'head': 'Turing.com',
#   'type': 'category_list',
#   'tail': 'Professional Services'},
#  {'head': 'Turing.com',
#   'type': 'category_list',
#   'tail': 'Science and Engineering'},
#  {'head': 'Turing.com', 'type': 'category_list', 'tail': 'Software'},
#  {'head': 'ezbob', 'type': 'category_list', 'tail': 'Financial Services'},
#  {'head': 'ezbob', 'type': 'category_list', 'tail': 'Software'},
#  {'head': 'Tmunity Therapeutics',
# ...
